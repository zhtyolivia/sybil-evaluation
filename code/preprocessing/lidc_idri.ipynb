# %%
import os 
import sys 

import nrrd 
import xml.etree.ElementTree as ET

import pandas as pd 
import numpy as np

# %%
# Get a list of DICOM directories

# %%
lidc_root_dir = '/workspace/radraid/luotingzhuang/dataset/LIDC/LIDC-IDRI'
os.listdir(lidc_root_dir)
# Out:
# ['LIDC-IDRI-0785',
#  'LIDC-IDRI-0442',
#  'LIDC-IDRI-0434',
#  'LIDC-IDRI-0692',
#  'LIDC-IDRI-0019',
#  'LIDC-IDRI-0024',
#  'LIDC-IDRI-0167',
#  'LIDC-IDRI-0454',
#  'LIDC-IDRI-0628',
#  'LIDC-IDRI-0901',
#  'LIDC-IDRI-0456',
#  'LIDC-IDRI-0559',
#  'LIDC-IDRI-0041',
#  'LIDC-IDRI-0214',
#  'LIDC-IDRI-0913',
#  'LIDC-IDRI-0460',
#  'LIDC-IDRI-0400',
#  'LIDC-IDRI-0188',
#  'LIDC-IDRI-0797',
#  'LIDC-IDRI-0191',
#  'LIDC-IDRI-0521',
#  'LIDC-IDRI-0029',
#  'LIDC-IDRI-0632',
#  'LIDC-IDRI-0915',
#  'LIDC-IDRI-0801',
#  'LIDC-IDRI-0125',
#  'LIDC-IDRI-0106',
#  'LIDC-IDRI-0862',
#  'LIDC-IDRI-0702',
#  'LIDC-IDRI-0703',
#  'LIDC-IDRI-0576',
#  'LIDC-IDRI-1000',
#  'LIDC-IDRI-0670',
#  'LIDC-IDRI-0571',
#  'LIDC-IDRI-0223',
#  'LIDC-IDRI-0260',
#  'LIDC-IDRI-0684',
#  'LIDC-IDRI-0486',
#  'LIDC-IDRI-0475',
#  'LIDC-IDRI-0244',
#  'LIDC-IDRI-0481',
#  'LIDC-IDRI-0037',
#  'LIDC-IDRI-0462',
#  'LIDC-IDRI-0765',
#  'LIDC-IDRI-0856',
#  'LIDC-IDRI-0216',
#  'LIDC-IDRI-0798',
# ...
