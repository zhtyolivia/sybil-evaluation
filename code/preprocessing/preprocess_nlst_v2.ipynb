# %%
import pydicom 
import os 
import pandas as pd 
import glob
import re
from datetime import datetime
import json
from tqdm import tqdm

# %% [markdown]
# # Get a list of directories for series that Sybil used as their test set

# %%
DATA_ROOT = '/workspace/data/lung/nlst/NLST_CT_raw/data'
FINAL_CORRECTED_PATH = '/workspace/home/tengyuezhang/sybil_cect/data/nlst_baseline/final_nlst_baseline_cases.csv'

# %%
NLST_ANNOT_PATH = '/workspace/home/tengyuezhang/sybil_cect/data/nlst_baseline/nlst_annotations.json'
PID2SPLIT_PATH = '/workspace/home/tengyuezhang/sybil_cect/data/nlst_baseline/pid2split.csv'

with open(NLST_ANNOT_PATH, 'r') as file:
    nlst_annot = json.load(file)
pid2split_df = pd.read_csv(PID2SPLIT_PATH)

# %% [markdown]
# # Try to fix cases with incorrect paths with accession number

# %%
INCORRECT_CASES = "/workspace/home/tengyuezhang/sybil_cect/data/nlst_baseline/nlst_baseline_cases_with_incorrect_paths.csv"
incorrect_df = pd.read_csv(INCORRECT_CASES)
incorrect_df
# Out:
#         pid  event  years_to_event  years_from_scan_to_diagnosis  \
# 0    100005      0             5.0                           NaN
# 1    100085      0             5.0                           NaN
# 2    101149      0             5.0                           NaN
# 3    101192      1             2.0                           2.0
# 4    101506      0             5.0                           NaN
# ..      ...    ...             ...                           ...
# 218  202143      0             5.0                           NaN
# 219  214822      1             0.0                           0.0
# 220  201769      1             0.0                           0.0
# 221  214683      1             0.0                           0.0
# 222  101066      1             0.0                           0.0
#
#      years_from_scan_to_last_followup  Year  timepoint  AccessionNumber  \
# 0                                 5.0  2000          1     4.514410e+05
# 1                                 6.0  1999          0     5.175680e+05
# 2                                 7.0  1999          0     2.798310e+05
# 3                                 6.0  1999          0     7.625110e+05
# 4                                 6.0  1999          0     9.390540e+05
# ..                                ...   ...        ...              ...
# 218                               6.0  1999          0     1.481356e+15
# 219                               5.0  1999          0     6.110254e+15
# 220                               6.0  1999          0              NaN
# 221                               7.0  1999          0              NaN
# 222                               7.0  1999          0     5.563820e+05
#
#                                              Directory
# 0    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 1    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 2    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 3    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 4    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# ..                                                 ...
# 218  /workspace/data/lung/nlst/NLST_CT_raw/data/202...
# 219  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 220  /workspace/data/lung/nlst/NLST_CT_raw/data/201...
# 221  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 222  /workspace/data/lung/nlst/NLST_CT_raw/data/101...
#
# [223 rows x 9 columns]

# %%
example = incorrect_df.iloc[0]
directory = example['Directory']
directory
# Out:
# '/workspace/data/lung/nlst/NLST_CT_raw/data/100005/01-02-2000-NA-NLST-LSS-07029/3.000000-1OPAGELS16D3702.514060.00.11.375-97837'

# %%
example_dcm_file = '/workspace/data/lung/nlst/NLST_CT_raw/data/100005/1.2.840.113654.2.55.153546750735549044492239658305292872969/1.2.840.113654.2.55.330656333774433317291205463243337143455/000000.dcm'
ds = pydicom.dcmread(example_dcm_file, stop_before_pixels=True)
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 190
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113654.2.55.46439685292490426795918354813307298735
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.31'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.46439685292490426795918354813307298735
# (0008, 0020) Study Date                          DA: '19990102'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0050) Accession Number                    SH: '688068'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'G26'
# (0008, 1030) Study Description                   LO: 'NLST-LSS'
# (0008, 103e) Series Description                  LO: '0,OPA,GE,LS16,BONE,370,2.5,140,60,0.1,1.4'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed16'
# (0010, 0010) Patient's Name                      PN: '089318^LSS'
# (0010, 0020) Patient ID                          LO: '100005'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1000) Other Patient IDs                   LO: '089318'
# (0012, 0010) Clinical Trial Sponsor Name         LO: 'National Cancer Institute'
# (0012, 0020) Clinical Trial Protocol ID          LO: 'NCT00047385'
# (0012, 0021) Clinical Trial Protocol Name        LO: 'NLST-LSS'
# (0012, 0030) Clinical Trial Site ID              LO: ''
# (0012, 0031) Clinical Trial Site Name            LO: ''
# (0012, 0040) Clinical Trial Subject ID           LO: '089318'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'T0'
# (0012, 0060) Clinical Trial Coordinating Center  LO: 'Washington U (images), Westat (assoc. data)'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['113100', '113101', '113103', '113105', '113109']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113103'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Graphics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'NLST'
# (0013, 1011) Private tag data                    UN: b'NLST'
# (0013, 1012) Private tag data                    UN: b'LSS\x00'
# (0013, 1013) Private tag data                    UN: b'70049004'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: '140.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: 'LightSpeedApps401.8_H4.0M4'
# (0018, 1100) Reconstruction Diameter             DS: '370.0'
# (0018, 1110) Distance Source to Detector         DS: '949.075012'
# (0018, 1111) Distance Source to Patient          DS: '541.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '174.199997'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '879'
# (0018, 1151) X-Ray Tube Current                  IS: '75'
# (0018, 1152) Exposure                            IS: '721'
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: '11'
# (0018, 1190) Focal Spot(s)                       DS: '0.7'
# (0018, 1210) Convolution Kernel                  SH: 'BONE'
# (0018, 9311) Spiral Pitch Factor                 FD: 1.375
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113654.2.55.153546750735549044492239658305292872969
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113654.2.55.330656333774433317291205463243337143455
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '106'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: [-185.000000, -166.000000, -226.175003]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.2.840.113654.2.55.237046056178662274713969152902867732343
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-226.175003'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0005) Image Dimensions                    SS: 2
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [007.226560e-01, 007.226560e-01]
# (0028, 0040) Image Format                        SH: 'RECT'
# (0028, 0060) Compression Code                    SH: 'NONE'
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0120) Pixel Padding Value                 US: 0
# (0028, 0200) Image Location                      SS: 32736
# (0028, 1050) Window Center                       DS: [45, 40]
# (0028, 1051) Window Width                        DS: [350, 340]
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'

# %%
# search by pid and accession number 
def find_and_check_accession(data_root, pid, accession_number):
    """
    Locate the first DICOM file under a PID directory and check if the accession number matches.

    Parameters:
        data_root (str): Root directory containing all PIDs.
        pid (str): The PID to search within.
        accession_number (str): The accession number to verify in the DICOM header.

    Returns:
        str: Path to the DICOM file if the accession number matches, otherwise None.
    """
    pid_dir = os.path.join(data_root, pid)
    # print(pid_dir)
    if not os.path.exists(pid_dir):
        print(f"PID directory {pid_dir} does not exist.")
        return None

    for root, dirs, files in os.walk(pid_dir):
        for file_name in files:
            if file_name.endswith(".dcm"):
                file_path = os.path.join(root, file_name)
                try:
                    ds = pydicom.dcmread(file_path, stop_before_pixels=True)
                    if hasattr(ds, "AccessionNumber"):
                        # print(ds.AccessionNumber)
                        if ds.AccessionNumber == accession_number:
                            # print('found')
                            return root
                except Exception as e:
                    print(f"Error reading DICOM file {file_path}: {e}")
    return None

# %%
result_path = find_and_check_accession(DATA_ROOT, str(example['pid']), str(int(example['AccessionNumber'])))
# Out:
# /workspace/data/lung/nlst/NLST_CT_raw/data/100005
# found

# %%
str(int(example['AccessionNumber']))
# Out:
# '451441'

# %%
result_path
# Out:
# '/workspace/data/lung/nlst/NLST_CT_raw/data/100005/1.2.840.113654.2.55.10251457513072085864761297205518907029/1.2.840.113654.2.55.148981425884825940179466259981962976653'

# %%
corrected_paths = []

for _, row in tqdm(incorrect_df.iterrows(), total=len(incorrect_df), desc="Correcting paths"):
    pid = str(row['pid'])
    accession_number = str(int(row['AccessionNumber']))
    corrected_path = find_and_check_accession(DATA_ROOT, pid, accession_number)
    corrected_paths.append(corrected_path)

# Add corrected paths to a new column
incorrect_df['CorrectedPath'] = corrected_paths
incorrect_df
# Out:
# Correcting paths:  34%|███████████████████████████████████████████████                                                                                             | 75/223 [01:49<03:36,  1.46s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 5
#       3 for _, row in tqdm(incorrect_df.iterrows(), total=len(incorrect_df), desc="Correcting paths"):
#       4     pid = str(row['pid'])
# ----> 5     accession_number = str(int(row['AccessionNumber']))
#       6     corrected_path = find_and_check_accession(DATA_ROOT, pid, accession_number)
#       7     corrected_paths.append(corrected_path)
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# # Some cases have missing accession num. Try path matching using suffix instead.

# %%
example['Directory']
# Out:
# '/workspace/data/lung/nlst/NLST_CT_raw/data/100005/01-02-2000-NA-NLST-LSS-07029/3.000000-1OPAGELS16D3702.514060.00.11.375-97837'

# %%
def extract_suffixes(path):
    """
    Extract time_suffix and series_suffix from the given path.

    Parameters:
        path (str): The file path.

    Returns:
        tuple: (time_suffix, series_suffix)
    """
    # Split the path into components
    parts = os.path.normpath(path).split(os.sep)
    
    # Extract time_suffix from the second-to-last directory
    # Example: "01-02-2000-NA-NLST-LSS-07029"
    time_part = parts[-2]  # Second-to-last directory
    time_suffix = time_part.split('-')[-1]  # Last part after splitting by '-'

    # Extract series_suffix from the last directory
    # Example: "3.000000-1OPAGELS16D3702.514060.00.11.375-97837"
    series_part = parts[-1]  # Last directory
    series_suffix = series_part.split('-')[-1]  # Last part after splitting by '-'

    return time_suffix, series_suffix

# %%
time_suffix, series_suffix = extract_suffixes(row['Directory'])

# %%
time_suffix
# Out:
# '80333'

# %%
series_suffix
# Out:
# '66541'

# %%
# in the target {DATA_ROOT}/{row['pid']} dirctory, 
# search for {DATA_ROOT}/{row['pid']}/*{time_suffix}/*{series_suffix}
def search_target_directory(data_root, pid, time_suffix, series_suffix):
    """
    params:
        data_root (str): NLST_CT_raw/data
        pid (str): 6-digit pid in string format 
        time_suffix (str): The time suffix to match.
        series_suffix (str): The series suffix to match.

    Returns:
        list: A list of matching paths.
    """
    pid_dir = os.path.join(data_root, pid)
    if not os.path.exists(pid_dir):
        print(f"PID directory {pid_dir} does not exist.")
        return []
    
    # use glob to search 
    search_pattern = os.path.join(pid_dir, f"*{time_suffix}*", f"*{series_suffix}*")
    matching_paths = glob.glob(search_pattern)
    if len(matching_paths) == 0: 
        print(f'Warning: path not found for {pid}, {time_suffix}, {series_suffix}')
    elif len(matching_paths) > 1: 
        print(f'Warning: multiple matches found for {pid}, {time_suffix}, {series_suffix}')
    return matching_paths

# %%
DATA_ROOT = "/workspace/data/lung/nlst/NLST_CT_raw/data/"
row = {'pid': '100005'}
time_suffix = "07029"
series_suffix = "97837"

matching_paths = search_target_directory(DATA_ROOT, row['pid'], time_suffix, series_suffix)
matching_paths
# Out:
# ['/workspace/data/lung/nlst/NLST_CT_raw/data/100005/1.2.840.113654.2.55.10251457513072085864761297205518907029/1.2.840.113654.2.55.17324290215190661437113320769488297837']

# %%
corrected_paths = []

for _, row in tqdm(incorrect_df.iterrows(), total=len(incorrect_df), desc="Correcting paths"):
    pid = str(row['pid'])
    time_suffix, series_suffix = extract_suffixes(row['Directory'])
    paths_found = search_target_directory(DATA_ROOT, pid, time_suffix, series_suffix)
    if len(paths_found) > 0: 
        corrected_paths.append(paths_found[0])
    else: 
        corrected_paths.append(None)
incorrect_df['CorrectedPath'] = corrected_paths
incorrect_df
# Out:
# Correcting paths:  52%|█████████████████████████████████████████████████████▋                                                  | 115/223 [00:00<00:00, 1143.49it/s]
# Warning: path not found for 218476, 13833, 52769
# Correcting paths: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 223/223 [00:00<00:00, 316.66it/s]
#         pid  event  years_to_event  years_from_scan_to_diagnosis  \
# 0    100005      0             5.0                           NaN
# 1    100085      0             5.0                           NaN
# 2    101149      0             5.0                           NaN
# 3    101192      1             2.0                           2.0
# 4    101506      0             5.0                           NaN
# ..      ...    ...             ...                           ...
# 218  202143      0             5.0                           NaN
# 219  214822      1             0.0                           0.0
# 220  201769      1             0.0                           0.0
# 221  214683      1             0.0                           0.0
# 222  101066      1             0.0                           0.0
#
#      years_from_scan_to_last_followup  Year  timepoint  AccessionNumber  \
# 0                                 5.0  2000          1     4.514410e+05
# 1                                 6.0  1999          0     5.175680e+05
# 2                                 7.0  1999          0     2.798310e+05
# 3                                 6.0  1999          0     7.625110e+05
# 4                                 6.0  1999          0     9.390540e+05
# ..                                ...   ...        ...              ...
# 218                               6.0  1999          0     1.481356e+15
# 219                               5.0  1999          0     6.110254e+15
# 220                               6.0  1999          0              NaN
# 221                               7.0  1999          0              NaN
# 222                               7.0  1999          0     5.563820e+05
#
#                                              Directory  \
# 0    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 1    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 2    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 3    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 4    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# ..                                                 ...
# 218  /workspace/data/lung/nlst/NLST_CT_raw/data/202...
# 219  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 220  /workspace/data/lung/nlst/NLST_CT_raw/data/201...
# 221  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 222  /workspace/data/lung/nlst/NLST_CT_raw/data/101...
#
#                                          CorrectedPath
# 0    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 1    /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 2    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 3    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# 4    /workspace/data/lung/nlst/NLST_CT_raw/data/101...
# ..                                                 ...
# 218  /workspace/data/lung/nlst/NLST_CT_raw/data/202...
# 219  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 220  /workspace/data/lung/nlst/NLST_CT_raw/data/201...
# 221  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 222  /workspace/data/lung/nlst/NLST_CT_raw/data/101...
#
# [223 rows x 10 columns]

# %%
corrected_df = incorrect_df.drop(columns=['Directory'])
corrected_df = corrected_df.rename(columns={'CorrectedPath': 'Directory'})

# %% [markdown]
# # Read the correct df and combine them. Then save.

# %%
correct_df = pd.read_csv("/workspace/home/tengyuezhang/sybil_cect/data/nlst_baseline/nlst_baseline_cases_with_correct_paths.csv")
correct_df
# Out:
#          pid  event  years_to_event  years_from_scan_to_diagnosis  \
# 0     100032      0             5.0                           NaN
# 1     100043      0             5.0                           NaN
# 2     100217      0             5.0                           NaN
# 3     100242      1             0.0                           0.0
# 4     100327      0             5.0                           NaN
# ...      ...    ...             ...                           ...
# 2100  212439      0             5.0                           NaN
# 2101  213775      0             5.0                           NaN
# 2102  216031      0             5.0                           NaN
# 2103  200988      0             5.0                           NaN
# 2104  208792      1             0.0                           0.0
#
#       years_from_scan_to_last_followup  Year  timepoint  AccessionNumber  \
# 0                                  7.0  1999          0     5.708600e+05
# 1                                  6.0  1999          0     1.326060e+05
# 2                                  5.0  1999          0     5.099390e+05
# 3                                  6.0  1999          0     3.961210e+05
# 4                                  6.0  1999          0     3.503540e+05
# ...                                ...   ...        ...              ...
# 2100                               6.0  1999          0     1.631518e+15
# 2101                               5.0  1999          0     3.231491e+15
# 2102                               5.0  1999          0     9.562193e+15
# 2103                               6.0  1999          0              NaN
# 2104                               3.0  1999          0              NaN
#
#                                               Directory
# 0     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 1     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 2     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 3     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 4     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# ...                                                 ...
# 2100  /workspace/data/lung/nlst/NLST_CT_raw/data/212...
# 2101  /workspace/data/lung/nlst/NLST_CT_raw/data/213...
# 2102  /workspace/data/lung/nlst/NLST_CT_raw/data/216...
# 2103  /workspace/data/lung/nlst/NLST_CT_raw/data/200...
# 2104  /workspace/data/lung/nlst/NLST_CT_raw/data/208...
#
# [2105 rows x 9 columns]

# %%
stacked_df = pd.concat([correct_df, corrected_df], ignore_index=True)
stacked_df
# Out:
#          pid  event  years_to_event  years_from_scan_to_diagnosis  \
# 0     100032      0             5.0                           NaN
# 1     100043      0             5.0                           NaN
# 2     100217      0             5.0                           NaN
# 3     100242      1             0.0                           0.0
# 4     100327      0             5.0                           NaN
# ...      ...    ...             ...                           ...
# 2323  202143      0             5.0                           NaN
# 2324  214822      1             0.0                           0.0
# 2325  201769      1             0.0                           0.0
# 2326  214683      1             0.0                           0.0
# 2327  101066      1             0.0                           0.0
#
#       years_from_scan_to_last_followup  Year  timepoint  AccessionNumber  \
# 0                                  7.0  1999          0     5.708600e+05
# 1                                  6.0  1999          0     1.326060e+05
# 2                                  5.0  1999          0     5.099390e+05
# 3                                  6.0  1999          0     3.961210e+05
# 4                                  6.0  1999          0     3.503540e+05
# ...                                ...   ...        ...              ...
# 2323                               6.0  1999          0     1.481356e+15
# 2324                               5.0  1999          0     6.110254e+15
# 2325                               6.0  1999          0              NaN
# 2326                               7.0  1999          0              NaN
# 2327                               7.0  1999          0     5.563820e+05
#
#                                               Directory
# 0     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 1     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 2     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 3     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# 4     /workspace/data/lung/nlst/NLST_CT_raw/data/100...
# ...                                                 ...
# 2323  /workspace/data/lung/nlst/NLST_CT_raw/data/202...
# 2324  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 2325  /workspace/data/lung/nlst/NLST_CT_raw/data/201...
# 2326  /workspace/data/lung/nlst/NLST_CT_raw/data/214...
# 2327  /workspace/data/lung/nlst/NLST_CT_raw/data/101...
#
# [2328 rows x 9 columns]

# %% [markdown]
# # For the missing one, manually changed it to:
# ### 218476/1.3.6.1.4.1.14519.5.2.1.7009.9004.112710550152264447844493113833/1.3.6.1.4.1.14519.5.2.1.7009.9004.169193826559204135185445821027

# %%
stacked_df.to_csv(FINAL_CORRECTED_PATH, index=False)

# %%
# 218476/1.3.6.1.4.1.14519.5.2.1.7009.9004.112710550152264447844493113833/1.3.6.1.4.1.14519.5.2.1.7009.9004.169193826559204135185445821027
